# %% [markdown]
# ## Natural language Processing(NLP):
# Natural language processing (NLP) is a machine learning technology that gives computers the ability to interpret, manipulate, and comprehend human language.
# Means giving computers ability to talk like Humans.
#
# ![nlp](images/nlp.png)

# %% [markdown]
# ## Text Summerization:
# Text summarization is the creation of a short, accurate, and fluent summary of a longer text document. It is used for generating a concise and meaningful summary of text from multiple text resources such as books, news articles, blog posts, research papers, emails, and tweets.
# Automatic Text Summarization gained attention as early as the 1950’s. A research paper, published by Hans Peter Luhn in the late 1950s, titled “The automatic creation of literature abstracts”, used features such as word frequency and phrase frequency to extract important sentences from the text for summarization purposes.
# Text summarization can broadly be divided into two categories — Extractive Summarization and Abstractive Summarization.
# #### Extractive Summarization: These methods rely on extracting several parts, such as phrases and sentences, from a piece of text and stack them together to create a summary. Therefore, identifying the right sentences for summarization is of utmost importance in an extractive method.
#
# #### Abstractive Summarization: These methods use advanced NLP techniques to generate an entirely new summary. Some parts of this summary may not even appear in the original text.
#
#
# ![image.png](attachment:a2ef24d8-3719-4a44-9f8d-9f7d0f6d9f55.png)
#
# We will be doing Extractive Summerization.

# %% [markdown]
# ## Tokenization :
# ### Tokenization in NLP (Natural Language Processing) is the process of breaking down a text piece into smaller units called tokens. These tokens can be words, characters, or even sentences, depending on the specific task and chosen approach.
# ![tokenization](images/tokenization.png)
#
# ## Stopwords :
# ### Stop words in NLP (Natural Language Processing) are a set of very common words that are often ignored or filtered out during text processing tasks. These words typically don't carry much meaning on their own .
# ![StopWords](images/StopWords.png)

# %% [markdown]
# ## Word Frequency Algorithm :
#
# ### 1.Iterate through the tokens (usually words) and count their occurrences in the text.
# ### 2.Exclude stop words (if you decided to remove them) from this calculation.
# ### 3.Store the word frequencies in a dictionary where each word is a key and its frequency is the value.
# ![word_frequency](images/word_frequency.png)
# ### 4.Find the maximum Frequency , and reassign the values of dictionary in proportion ith Maximum frequency.
# ### 5.Sentences with more occurrences of high-frequency words (excluding stop words) receive higher scores.
# ### 6. The sentences with the highest scores are selected to form the summary. Typically, a predefined number of top-scoring sentences are chosen (e.g., top 10) and Summary is created.

# %% [markdown]
# ### LIBRARIES :
# ![nlp_libraries](images/libraries.png)
#
# #### We will be using "NLTK(Natural language ToolKit)" because of ease of use,wide range of functionalities and active community.
# #### Also we will be using another Library called "HEAPQ" ,it used for dealing ith large data and finding max,min,priority,sets.

# %% [markdown]
# ### PageRank and TextRank Algorithm:
#
# ![pagerank1](images/pagerank1.png)
# ![pagerank2](images/pagerank2.png)
# ![pagerank3](images/pagerank3.png)

# %% [markdown]
# ### Theory Ends .Let's get to coding !!!
